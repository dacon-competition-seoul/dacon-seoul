# %%
import pandas as pd 
import geopandas as gpd

# %%
df = pd.read_csv("data/서울특별시 공공자전거 대여이력 정보_22.06.csv", encoding="cp949")

# %%
gdf = gpd.read_file("data/강서구/NGII_DTM_V2_5000_서울_강서구/37608053.zip")

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
df = df[df["이용거리"]>0]

# %%
df
# Out:
#              자전거번호                 대여일시  대여 대여소번호         대여 대여소명  대여거치대  \
# 0        SPB-59614  2022-06-01 06:36:04       668    서울축산농협(장안지점)      0
# 1        SPB-33195  2022-06-01 07:57:48       529    장한평역 8번 출구 앞      0
# 2        SPB-56997  2022-06-01 12:26:32       529    장한평역 8번 출구 앞      0
# 3        SPB-51938  2022-06-01 21:10:16      3560  성동구 견인차량 보관소 앞      0
# 4        SPB-63085  2022-06-02 08:29:11       529    장한평역 8번 출구 앞      0
# ...            ...                  ...       ...             ...    ...
# 4196967  SPB-59800  2022-06-28 08:21:09       296      KT플라자 영등포점      0
# 4196969  SPB-59006  2022-06-29 07:54:56       832     이촌1동 주민센터 뒤      0
# 4196971  SPB-57462  2022-06-04 00:03:33      1360             정릉역      0
# 4196972  SPB-47177  2022-06-07 09:15:45       557      도선동 주민센터 앞      0
# 4196973  SPB-30341  2022-06-20 17:11:30      3600     사근빗물펌프장 건너편      0
#
#                         반납일시  반납대여소번호      반납대여소명  반납거치대  이용시간     이용거리
# ...

# %%
df = pd.read_csv("data/서울특별시 공공자전거 일별 대여건수_21.02.01_21.06.30.csv", encoding="cp949")

# %%
df = df.iloc[:,:2]

# %%
df = df.dropna()

# %%
df["대여건수"] = df["대여건수"].str.replace(",", "").astype(int)
# Out:
# /tmp/ipykernel_21595/3493396379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["대여건수"] = df["대여건수"].str.replace(",", "").astype(int)

# %%
df.대여건수.plot()
# Out:
# <AxesSubplot:>
