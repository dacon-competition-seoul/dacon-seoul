# %%
import pandas as pd

# %%
df = pd.read_csv("./공공자전거 대여소 정보(21.01.31 기준).csv", encoding="cp949")

# %%
df.dropna(subset=["보관소(대여소)명"])
# Out:
#       대여소\n번호          보관소(대여소)명 소재지(위치)            Unnamed: 3 Unnamed: 4  \
# 4       301.0        경복궁역 7번출구 앞     종로구   서울특별시 종로구 사직로 지하130  37.575794
# 5       302.0        경복궁역 4번출구 뒤     종로구   서울특별시 종로구 사직로 지하130  37.575947
# 6       303.0        광화문역 1번출구 앞     종로구  서울특별시 종로구 세종대로 지하189  37.571770
# 7       304.0        광화문역 2번출구 앞     종로구  서울특별시 종로구 세종대로 지하172  37.572113
# 8       305.0             종로구청 옆     종로구      서울특별시 종로구 삼봉로 43  37.572582
# ...       ...                ...     ...                   ...        ...
# 2153   1085.0       래미안 솔베뉴(고덕로)     강동구              양재대로1650  37.554569
# 2154   1086.0      래미안 솔베뉴(구천면로)     강동구              양재대로1650  37.550598
# 2155   1088.0          풍납사거리(강동)     강동구              성내동451-3  37.528122
# 2156   1089.0  고덕 래미안힐스테이트(201동)     강동구               고덕동 675  37.560600
# 2157   1090.0        상일동역 2번출구 앞     강동구               고덕로 333  37.556789
#
#       Unnamed: 5      설치\n시기 설치형태 Unnamed: 8 운영\n방식
# ...
